# %% [markdown]
# # 📘 Aula 00 - Desenvolvendo minha primeira rede neural

# %% [markdown]
# # Laboratório: aprendendo a função $y = 2x - 1$ com o TensorFlow
# Neste laboratório vamos construir, passo a passo, uma pequena experiência de aprendizado de máquina.
# O objetivo é mostrar, de forma didática, como:
# 1. Gerar dados sintéticos a partir de uma função conhecida;
# 2. Visualizar esses dados em um gráfico interativo com Plotly;
# 3. Criar uma reda usando uma **rede neural simples com TensorFlow**.
#
# Todo o texto está em português e comentado como se fosse uma aula.

# %% [markdown]
# ## Objetivos de aprendizagem
# - Compreender a relação entre dados de entrada e saída para uma função linear simples;
# - Visualizar os dados e o modelo ajustado usando Plotly com tema `ggplot2`;
# - Ver como o TensorFlow automatiza esse processo.
#
# **Documentações úteis:**
# - TensorFlow: https://www.tensorflow.org/
# - Keras (dentro do TensorFlow): https://www.tensorflow.org/api_docs/python/tf/keras
# - Plotly Express: https://plotly.com/python/plotly-express/
# - Plotly templates: https://plotly.com/python/templates/

# %%
# Importar bibliotecas

# %% [markdown]
# ## 1. Gerando os dados da função
# Vamos criar alguns valores de entrada `x` e calcular a saída `y` usando a função alvo:
# \[ y = 2x - 1 \]
# Também vamos visualizar esses pontos.

# %%
# Criar dados e plotar no gráfico

# %% [markdown]
# ## 2. Construindo um modelo simples com TensorFlow
# Agora vamos deixar o TensorFlow fazer o trabalho pesado. A ideia é a mesma:
# 1. Criamos um modelo sequencial com uma única camada densa de 1 neurônio;
# 2. Compilamos o modelo informando o otimizador e a função de perda;
# 3. Treinamos o modelo com os mesmos dados que geramos.
#
# Documentações recomendadas:
# - Sequential: https://www.tensorflow.org/api_docs/python/tf/keras/Sequential
# - Camada Dense: https://keras.io/api/layers/core_layers/dense/
# - Otimizadores: https://keras.io/api/optimizers/
# - Funções de perda: https://keras.io/api/losses/

# %%
# Construir um modelo de Deep Learning

# %% [markdown]
# ## 4. Fazendo previsões
# Se o modelo aprendeu mesmo a função $y = 2x - 1$, então para uma entrada, por exemplo, `10.0`,
# ele deve devolver um valor próximo de `19`.

# %%
# Fazer previsões
